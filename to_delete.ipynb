# %%
from django_flight_tracker.flightsearch import *

# %%
apikey = 'hsgRmFhjJRKIzN6o0MEovJXr9VJFxQQh'

inputs_round = {
    'flight_type': 'round',
    'fly_from': 'RHO',
    'fly_to': 'MIA',
    'date_from': '01/10/2020',
    'date_to': '15/12/2020',
    'return_from': '01/10/2020',
    'return_to': '15/12/2020',
    'nights_in_dst_from': 5, 
    'nights_in_dst_to': 15,
    'max_fly_duration': 25,
    'selected_cabins': 'M',  # M (economy), W (economy premium), C (business), F (first class)
    'partner_market': 'es',
    'locale': 'us',
    'curr': 'EUR',
    'price_from': 0,
    'price_to': 1200,
    'max_stopovers': 3,
    'sort': 'price',
    'asc': 1
}

first_n_options = search(apikey, parameters=inputs_round, n=10)
# Out:
# Getting the data...
# Data loaded from cache

# %%
first_n_options
# Out:
# {1: {'option': 1,
#   'link': 'http://tinyurl.com/ya7yk5tl',
#   'price': 478,
#   'duration_total': '45h30m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '24h25m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sat 10-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sat 10-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 23-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 24-Oct-2020 23:40'},
#  2: {'option': 2,
#   'link': 'http://tinyurl.com/yb9kqq4t',
#   'price': 481,
#   'duration_total': '43h55m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '22h50m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 04-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 04-Oct-2020 20:40',
#   'inbound_departure_time': 'Sat 10-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sun 11-Oct-2020 22:05'},
#  3: {'option': 3,
#   'link': 'http://tinyurl.com/ycebolpz',
#   'price': 494,
#   'duration_total': '42h15m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '21h10m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 11-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 11-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 23-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 24-Oct-2020 20:25'},
#  4: {'option': 4,
#   'link': 'http://tinyurl.com/y8gy2xt5',
#   'price': 497,
#   'duration_total': '42h15m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '21h10m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sat 10-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sat 10-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 23-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 24-Oct-2020 20:25'},
#  5: {'option': 5,
#   'link': 'http://tinyurl.com/y8xjpd5n',
#   'price': 504,
#   'duration_total': '45h30m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '24h25m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 04-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 04-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 16-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 17-Oct-2020 23:40'},
#  6: {'option': 6,
#   'link': 'http://tinyurl.com/ycg2b22g',
#   'price': 504,
#   'duration_total': '45h30m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '24h25m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 11-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 11-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 16-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 17-Oct-2020 23:40'},
#  7: {'option': 7,
#   'link': 'http://tinyurl.com/ycmumm98',
#   'price': 506,
#   'duration_total': '45h30m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '24h25m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sat 17-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sat 17-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 23-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 24-Oct-2020 23:40'},
#  8: {'option': 8,
#   'link': 'http://tinyurl.com/y7wofnxo',
#   'price': 507,
#   'duration_total': '41h25m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '20h20m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 11-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 11-Oct-2020 20:40',
#   'inbound_departure_time': 'Fri 23-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sat 24-Oct-2020 19:35'},
#  9: {'option': 9,
#   'link': 'http://tinyurl.com/ycf7ybuh',
#   'price': 507,
#   'duration_total': '43h55m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '22h50m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 11-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 11-Oct-2020 20:40',
#   'inbound_departure_time': 'Sat 17-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sun 18-Oct-2020 22:05'},
#  10: {'option': 10,
#   'link': 'http://tinyurl.com/y8gtboy4',
#   'price': 507,
#   'duration_total': '43h55m',
#   'duration_outbound': '21h05m',
#   'duration_inbound': '22h50m',
#   'outbound_from': 'RHO',
#   'inbound_from': 'MIA',
#   'outbound_to': 'ATH',
#   'inbound_to': 'LIS',
#   'outbound_departure_time': 'Sun 04-Oct-2020 06:35',
#   'outbound_arrival_time': 'Sun 04-Oct-2020 20:40',
#   'inbound_departure_time': 'Sat 17-Oct-2020 16:15',
#   'inbound_arrival_time': 'Sun 18-Oct-2020 22:05'}}
